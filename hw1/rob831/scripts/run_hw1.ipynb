# %% [markdown]
# ##Setup
#
# You will need to make a copy of this notebook in your Google Drive before you can edit the homework files. You can do so with **File &rarr; Save a copy in Drive**. Please run on GPU: Runtime -> Change runtime type -> Hardware accelerator -> T4 GPU

# %%
#@title mount your Google Drive
#@markdown Your work will be stored in a folder called `hw_16831` by default to prevent Colab instance timeouts from deleting your edits.

import os
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#@title set up mount symlink

DRIVE_PATH = '/content/gdrive/My\ Drive/hw_16831'
DRIVE_PYTHON_PATH = DRIVE_PATH.replace('\\', '')
if not os.path.exists(DRIVE_PYTHON_PATH):
  # %mkdir $DRIVE_PATH

## the space in `My Drive` causes some issues,
## make a symlink to avoid this
SYM_PATH = '/content/hw_16831'
if not os.path.exists(SYM_PATH):
  # !ln -s $DRIVE_PATH $SYM_PATH
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\ '
# <>:3: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipython-input-3425321108.py:3: SyntaxWarning: invalid escape sequence '\ '
#   DRIVE_PATH = '/content/gdrive/My\ Drive/hw_16831'

# %%
#@title apt install requirements

#@markdown Run each section with Shift+Enter

#@markdown Double-click on section headers to show code.

# !apt update
# !apt install -y --no-install-recommends \
        build-essential \
        curl \
        git \
        gnupg2 \
        make \
        cmake \
        ffmpeg \
        swig \
        libz-dev \
        unzip \
        zlib1g-dev \
        libglfw3 \
        libglfw3-dev \
        libxrandr2 \
        libxinerama-dev \
        libxi6 \
        libxcursor-dev \
        libgl1-mesa-dev \
        libgl1-mesa-glx \
        libglew-dev \
        libosmesa6-dev \
        lsb-release \
        ack-grep \
        patchelf \
        wget \
        xpra \
        xserver-xorg-dev \
        xvfb \
        python3-opengl \
        ffmpeg
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,341 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.8 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,892 kB]
# Get:13 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,014 kB]
# Get:15 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:16 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,677 kB]
# Get:18 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,712 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [70.9 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,608 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,607 kB]
# Get:22 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.9 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [37.2 kB]
# Get:25 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [45.0 kB]
# Get:26 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,388 kB]
# Get:27 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 Packages [75.3 kB]
# Get:28 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [62.6 kB]
# Get:29 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,297 kB]
# Fetched 39.5 MB in 5s (8,191 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 119 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'zlib1g-dev' instead of 'libz-dev'
# Note, selecting 'ack' instead of 'ack-grep'
# build-essential is already the newest version (12.9ubuntu3).
# libxi6 is already the newest version (2:1.8-1build1).
# libxi6 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# libxrandr2 set to manually installed.
# lsb-release is already the newest version (11.1.0ubuntu4).
# lsb-release set to manually installed.
# make is already the newest version (4.3-4.1build1).
# make set to manually installed.
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# curl is already the newest version (7.81.0-1ubuntu1.21).
# git is already the newest version (1:2.34.1-1ubuntu1.15).
# unzip is already the newest version (6.0-26ubuntu3.2).
# wget is already the newest version (1.21.2-2ubuntu1.1).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# zlib1g-dev set to manually installed.
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# libgl1-mesa-glx is already the newest version (23.0.4-0ubuntu1~22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# The following additional packages will be installed:
#   dirmngr freeglut3 gir1.2-atk-1.0 gir1.2-gtk-3.0 gnupg gnupg-l10n gnupg-utils
#   gpg gpg-agent gpg-wks-client gpg-wks-server gpgconf gpgsm gpgv
#   keyboard-configuration libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data
#   libatspi2.0-0 libdrm-dev libegl-dev libfile-next-perl libfontenc-dev
#   libgl-dev libgles-dev libgles1 libglew2.2 libglu1-mesa libglu1-mesa-dev
#   libglvnd-core-dev libglvnd-dev libglx-dev libgtk-3-0 libgtk-3-common
#   liblocale-gettext-perl libopengl-dev libosmesa6 libpciaccess-dev
#   libturbojpeg libudev1 libxcomposite1 libxcvt-dev libxcvt0 libxfixes-dev
#   libxfont-dev libxkbfile-dev libxtst6 mesa-common-dev python3-cairo
#   python3-rencode swig4.0 udev x11-xserver-utils xserver-xorg-core
#   xserver-xorg-video-dummy
# Suggested packages:
#   pinentry-gnome3 tor parcimonie xloadimage scdaemon glew-utils libvulkan1
#   libglfw3-doc gvfs libgle3 python3-numpy python3-tk swig-doc swig-examples
#   swig4.0-examples swig4.0-doc nickle cairo-5c xorg-docs-core openssh-server
#   python3-pyopencl gstreamer1.0-plugins-base gstreamer1.0-plugins-good
#   | gstreamer1.0-plugins-ugly | gstreamer1.0-plugins-bad python3-gst-1.0
#   pulseaudio pulseaudio-utils python3-avahi python3-netifaces cups-client
#   cups-common cups-filters cups-pdf python3-cups python3-opencv
#   v4l2loopback-dkms python3-yaml python3-uinput xfonts-100dpi | xfonts-75dpi
#   xfonts-scalable
# Recommended packages:
#   at-spi2-core libegl1-mesa-dev libvulkan-dev libwayland-dev libxrandr-dev
#   libgtk-3-bin librsvg2-common systemd-hwe-hwdb gir1.2-appindicator3-0.1
#   python3-numpy python3-paramiko python3-dns ssh-askpass python3-lz4
#   python3-lzo python3-brotli python3-pil python3-setproctitle python3-zeroconf
#   python3-kerberos python3-gssapi python3-xdg python3-uritools python3-cpuinfo
#   python3-pyinotify xcvt
# The following NEW packages will be installed:
#   ack freeglut3 gir1.2-atk-1.0 gir1.2-gtk-3.0 keyboard-configuration
#   libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data libatspi2.0-0 libdrm-dev
#   libegl-dev libfile-next-perl libfontenc-dev libgl-dev libgl1-mesa-dev
#   libgles-dev libgles1 libglew-dev libglew2.2 libglfw3 libglfw3-dev
#   libglu1-mesa libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev
#   libgtk-3-0 libgtk-3-common liblocale-gettext-perl libopengl-dev libosmesa6
#   libosmesa6-dev libpciaccess-dev libturbojpeg libxcomposite1 libxcursor-dev
#   libxcvt-dev libxcvt0 libxfixes-dev libxfont-dev libxinerama-dev
#   libxkbfile-dev libxtst6 mesa-common-dev patchelf python3-cairo
#   python3-opengl python3-rencode swig swig4.0 udev x11-xserver-utils xpra
#   xserver-xorg-core xserver-xorg-dev xserver-xorg-video-dummy
# The following packages will be upgraded:
#   dirmngr gnupg gnupg-l10n gnupg-utils gnupg2 gpg gpg-agent gpg-wks-client
#   gpg-wks-server gpgconf gpgsm gpgv libudev1
# 13 upgraded, 56 newly installed, 0 to remove and 106 not upgraded.
# Need to get 22.5 MB of archives.
# After this operation, 86.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblocale-gettext-perl amd64 1.07-4build3 [17.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 keyboard-configuration all 1.205ubuntu3 [206 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.17 [76.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gpg-wks-client amd64 2.2.27-3ubuntu2.5 [62.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dirmngr amd64 2.2.27-3ubuntu2.5 [293 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gpg-wks-server amd64 2.2.27-3ubuntu2.5 [57.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gnupg-utils amd64 2.2.27-3ubuntu2.5 [309 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gpg-agent amd64 2.2.27-3ubuntu2.5 [209 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gpg amd64 2.2.27-3ubuntu2.5 [519 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gpgconf amd64 2.2.27-3ubuntu2.5 [94.3 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gnupg-l10n all 2.2.27-3ubuntu2.5 [54.5 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gnupg all 2.2.27-3ubuntu2.5 [315 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gpgsm amd64 2.2.27-3ubuntu2.5 [197 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gpgv amd64 2.2.27-3ubuntu2.5 [137 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.17 [1,557 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfile-next-perl all 1.18-1 [17.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ack all 3.5.0-1 [70.4 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3 amd64 2.8.1-6 [74.0 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 gir1.2-atk-1.0 amd64 2.36.0-3build1 [21.0 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-common all 3.24.33-1ubuntu2.2 [239 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-0 amd64 3.24.33-1ubuntu2.2 [3,053 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-gtk-3.0 amd64 3.24.33-1ubuntu2.2 [240 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpciaccess-dev amd64 0.16-3 [21.9 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-dev amd64 2.4.113-2~ubuntu0.22.04.1 [292 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc-dev amd64 1:1.1.4-1build3 [15.4 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [6,848 B]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglew2.2 amd64 2.2.0-4 [196 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa-dev amd64 9.0.2-1 [231 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglew-dev amd64 2.2.0-4 [287 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglfw3 amd64 3.3.6-1 [83.2 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglfw3-dev amd64 3.3.6-1 [41.1 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libturbojpeg amd64 2.1.2-0ubuntu1 [175 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfixes-dev amd64 1:6.0.0-1 [12.2 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcursor-dev amd64 1:1.2.0-2build4 [28.2 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt0 amd64 0.1.1-3 [5,494 B]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt-dev amd64 0.1.1-3 [3,242 B]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont-dev amd64 1:2.0.5-1build1 [128 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxinerama-dev amd64 2:1.1.4-3 [8,104 B]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile-dev amd64 1:1.1.0-1build3 [85.0 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mesa-common-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [2,208 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/universe amd64 patchelf amd64 0.14.3-1 [72.1 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-cairo amd64 1.20.1-3build1 [73.7 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-opengl all 3.1.5+dfsg-1 [605 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-rencode amd64 1.0.6-2build1 [45.2 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xserver-utils amd64 7.7+9build1 [170 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-core amd64 2:21.1.4-2ubuntu1.7~22.04.16 [1,478 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/main amd64 xserver-xorg-video-dummy amd64 1:0.3.8-2build1 [9,578 B]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xpra amd64 3.1-1build5 [3,396 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-dev amd64 2:21.1.4-2ubuntu1.7~22.04.16 [205 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 gnupg2 all 2.2.27-3ubuntu2.5 [5,544 B]
# Get:68 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libosmesa6 amd64 23.2.1-1ubuntu3.1~22.04.3 [3,115 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libosmesa6-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [8,984 B]
# Fetched 22.5 MB in 2s (14.3 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package liblocale-gettext-perl.
# (Reading database ... 121689 files and directories currently installed.)
# Preparing to unpack .../liblocale-gettext-perl_1.07-4build3_amd64.deb ...
# Unpacking liblocale-gettext-perl (1.07-4build3) ...
# Selecting previously unselected package keyboard-configuration.
# Preparing to unpack .../keyboard-configuration_1.205ubuntu3_all.deb ...
# Unpacking keyboard-configuration (1.205ubuntu3) ...
# Preparing to unpack .../libudev1_249.11-0ubuntu3.17_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.17) over (249.11-0ubuntu3.12) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.17) ...
# (Reading database ... 121723 files and directories currently installed.)
# Preparing to unpack .../00-gpg-wks-client_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gpg-wks-client (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../01-dirmngr_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking dirmngr (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../02-gpg-wks-server_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gpg-wks-server (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../03-gnupg-utils_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gnupg-utils (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../04-gpg-agent_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gpg-agent (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../05-gpg_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gpg (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../06-gpgconf_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gpgconf (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../07-gnupg-l10n_2.2.27-3ubuntu2.5_all.deb ...
# Unpacking gnupg-l10n (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../08-gnupg_2.2.27-3ubuntu2.5_all.deb ...
# Unpacking gnupg (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../09-gpgsm_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gpgsm (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Preparing to unpack .../10-gpgv_2.2.27-3ubuntu2.5_amd64.deb ...
# Unpacking gpgv (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Setting up gpgv (2.2.27-3ubuntu2.5) ...
# Selecting previously unselected package udev.
# (Reading database ... 121723 files and directories currently installed.)
# Preparing to unpack .../00-udev_249.11-0ubuntu3.17_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.17) ...
# Selecting previously unselected package libfile-next-perl.
# Preparing to unpack .../01-libfile-next-perl_1.18-1_all.deb ...
# Unpacking libfile-next-perl (1.18-1) ...
# Selecting previously unselected package ack.
# Preparing to unpack .../02-ack_3.5.0-1_all.deb ...
# Unpacking ack (3.5.0-1) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../03-freeglut3_2.8.1-6_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-6) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../04-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../05-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package gir1.2-atk-1.0:amd64.
# Preparing to unpack .../06-gir1.2-atk-1.0_2.36.0-3build1_amd64.deb ...
# Unpacking gir1.2-atk-1.0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libatspi2.0-0:amd64.
# Preparing to unpack .../07-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../08-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../09-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package libgtk-3-common.
# Preparing to unpack .../10-libgtk-3-common_3.24.33-1ubuntu2.2_all.deb ...
# Unpacking libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgtk-3-0:amd64.
# Preparing to unpack .../11-libgtk-3-0_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package gir1.2-gtk-3.0:amd64.
# Preparing to unpack .../12-gir1.2-gtk-3.0_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking gir1.2-gtk-3.0:amd64 (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libpciaccess-dev:amd64.
# Preparing to unpack .../13-libpciaccess-dev_0.16-3_amd64.deb ...
# Unpacking libpciaccess-dev:amd64 (0.16-3) ...
# Selecting previously unselected package libdrm-dev:amd64.
# Preparing to unpack .../14-libdrm-dev_2.4.113-2~ubuntu0.22.04.1_amd64.deb ...
# Unpacking libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../15-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../16-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../17-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libfontenc-dev:amd64.
# Preparing to unpack .../18-libfontenc-dev_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc-dev:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../19-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../20-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../21-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../22-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../23-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../24-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libglew2.2:amd64.
# Preparing to unpack .../25-libglew2.2_2.2.0-4_amd64.deb ...
# Unpacking libglew2.2:amd64 (2.2.0-4) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../26-libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglu1-mesa-dev:amd64.
# Preparing to unpack .../27-libglu1-mesa-dev_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglew-dev:amd64.
# Preparing to unpack .../28-libglew-dev_2.2.0-4_amd64.deb ...
# Unpacking libglew-dev:amd64 (2.2.0-4) ...
# Selecting previously unselected package libglfw3:amd64.
# Preparing to unpack .../29-libglfw3_3.3.6-1_amd64.deb ...
# Unpacking libglfw3:amd64 (3.3.6-1) ...
# Selecting previously unselected package libglfw3-dev:amd64.
# Preparing to unpack .../30-libglfw3-dev_3.3.6-1_amd64.deb ...
# Unpacking libglfw3-dev:amd64 (3.3.6-1) ...
# Selecting previously unselected package libturbojpeg:amd64.
# Preparing to unpack .../31-libturbojpeg_2.1.2-0ubuntu1_amd64.deb ...
# Unpacking libturbojpeg:amd64 (2.1.2-0ubuntu1) ...
# Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../32-libxfixes-dev_1%3a6.0.0-1_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:6.0.0-1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../33-libxcursor-dev_1%3a1.2.0-2build4_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.2.0-2build4) ...
# Selecting previously unselected package libxcvt0:amd64.
# Preparing to unpack .../34-libxcvt0_0.1.1-3_amd64.deb ...
# Unpacking libxcvt0:amd64 (0.1.1-3) ...
# Selecting previously unselected package libxcvt-dev:amd64.
# Preparing to unpack .../35-libxcvt-dev_0.1.1-3_amd64.deb ...
# Unpacking libxcvt-dev:amd64 (0.1.1-3) ...
# Selecting previously unselected package libxfont-dev.
# Preparing to unpack .../36-libxfont-dev_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont-dev (1:2.0.5-1build1) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../37-libxinerama-dev_2%3a1.1.4-3_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.4-3) ...
# Selecting previously unselected package libxkbfile-dev:amd64.
# Preparing to unpack .../38-libxkbfile-dev_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile-dev:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../39-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package mesa-common-dev:amd64.
# Preparing to unpack .../40-mesa-common-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking mesa-common-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package patchelf.
# Preparing to unpack .../41-patchelf_0.14.3-1_amd64.deb ...
# Unpacking patchelf (0.14.3-1) ...
# Selecting previously unselected package python3-cairo:amd64.
# Preparing to unpack .../42-python3-cairo_1.20.1-3build1_amd64.deb ...
# Unpacking python3-cairo:amd64 (1.20.1-3build1) ...
# Selecting previously unselected package python3-opengl.
# Preparing to unpack .../43-python3-opengl_3.1.5+dfsg-1_all.deb ...
# Unpacking python3-opengl (3.1.5+dfsg-1) ...
# Selecting previously unselected package python3-rencode.
# Preparing to unpack .../44-python3-rencode_1.0.6-2build1_amd64.deb ...
# Unpacking python3-rencode (1.0.6-2build1) ...
# Selecting previously unselected package swig4.0.
# Preparing to unpack .../45-swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../46-swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Selecting previously unselected package x11-xserver-utils.
# Preparing to unpack .../47-x11-xserver-utils_7.7+9build1_amd64.deb ...
# Unpacking x11-xserver-utils (7.7+9build1) ...
# Selecting previously unselected package xserver-xorg-core.
# Preparing to unpack .../48-xserver-xorg-core_2%3a21.1.4-2ubuntu1.7~22.04.16_amd64.deb ...
# Unpacking xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.16) ...
# Selecting previously unselected package xserver-xorg-video-dummy.
# Preparing to unpack .../49-xserver-xorg-video-dummy_1%3a0.3.8-2build1_amd64.deb ...
# Unpacking xserver-xorg-video-dummy (1:0.3.8-2build1) ...
# Selecting previously unselected package xpra.
# Preparing to unpack .../50-xpra_3.1-1build5_amd64.deb ...
# Unpacking xpra (3.1-1build5) ...
# Selecting previously unselected package xserver-xorg-dev.
# Preparing to unpack .../51-xserver-xorg-dev_2%3a21.1.4-2ubuntu1.7~22.04.16_amd64.deb ...
# Unpacking xserver-xorg-dev (2:21.1.4-2ubuntu1.7~22.04.16) ...
# Preparing to unpack .../52-gnupg2_2.2.27-3ubuntu2.5_all.deb ...
# Unpacking gnupg2 (2.2.27-3ubuntu2.5) over (2.2.27-3ubuntu2.4) ...
# Selecting previously unselected package libosmesa6:amd64.
# Preparing to unpack .../53-libosmesa6_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libosmesa6:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libosmesa6-dev:amd64.
# Preparing to unpack .../54-libosmesa6-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libosmesa6-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libglfw3:amd64 (3.3.6-1) ...
# Setting up libpciaccess-dev:amd64 (0.16-3) ...
# Setting up freeglut3:amd64 (2.8.1-6) ...
# Setting up python3-cairo:amd64 (1.20.1-3build1) ...
# Setting up python3-rencode (1.0.6-2build1) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libfontenc-dev:amd64 (1:1.1.4-1build3) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up x11-xserver-utils (7.7+9build1) ...
# Setting up libxfixes-dev:amd64 (1:6.0.0-1) ...
# Setting up gnupg-l10n (2.2.27-3ubuntu2.5) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up libfile-next-perl (1.18-1) ...
# Setting up udev (249.11-0ubuntu3.17) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libxinerama-dev:amd64 (2:1.1.4-3) ...
# Setting up libglew2.2:amd64 (2.2.0-4) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up libturbojpeg:amd64 (2.1.2-0ubuntu1) ...
# Setting up ack (3.5.0-1) ...
# Setting up gpgconf (2.2.27-3ubuntu2.5) ...
# Setting up libxcvt0:amd64 (0.1.1-3) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up patchelf (0.14.3-1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up liblocale-gettext-perl (1.07-4build3) ...
# Setting up gpg (2.2.27-3ubuntu2.5) ...
# Setting up libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Setting up gnupg-utils (2.2.27-3ubuntu2.5) ...
# Setting up libxkbfile-dev:amd64 (1:1.1.0-1build3) ...
# Setting up libosmesa6:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Setting up gpg-agent (2.2.27-3ubuntu2.5) ...
# Setting up libxcvt-dev:amd64 (0.1.1-3) ...
# Setting up libglfw3-dev:amd64 (3.3.6-1) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up gir1.2-atk-1.0:amd64 (2.36.0-3build1) ...
# Setting up libxcursor-dev:amd64 (1:1.2.0-2build4) ...
# Setting up libxfont-dev (1:2.0.5-1build1) ...
# Setting up gpgsm (2.2.27-3ubuntu2.5) ...
# Setting up python3-opengl (3.1.5+dfsg-1) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up dirmngr (2.2.27-3ubuntu2.5) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Setting up libosmesa6-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up gpg-wks-server (2.2.27-3ubuntu2.5) ...
# Setting up mesa-common-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up keyboard-configuration (1.205ubuntu3) ...
# Your console font configuration will be updated the next time your system
# boots. If you want to update it now, run 'setupcon' from a virtual console.
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up gpg-wks-client (2.2.27-3ubuntu2.5) ...
# Setting up xserver-xorg-dev (2:21.1.4-2ubuntu1.7~22.04.16) ...
# Setting up xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.16) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up xserver-xorg-video-dummy (1:0.3.8-2build1) ...
# Setting up libglew-dev:amd64 (2.2.0-4) ...
# Setting up libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up gnupg (2.2.27-3ubuntu2.5) ...
# Setting up gnupg2 (2.2.27-3ubuntu2.5) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Processing triggers for shared-mime-info (2.1-2) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.6) ...
# Setting up libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# Setting up gir1.2-gtk-3.0:amd64 (3.24.33-1ubuntu2.2) ...
# Setting up xpra (3.1-1build5) ...
# ......+....+..+...+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*...........+.......+......+..+...+...+......+...+............+.+..............+...+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*........+...+....+...+.....+.+.....+.+.....+........................+.+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...+.+..............+.......+...............+..+...+....+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*.........+........+...+...+.+.....+..........+...+..+......+.......+..+.+..+...+....+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*......................+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# -----
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...

# %%
#@title clone homework repo

# %cd $SYM_PATH
# %rm -rf 16831-S26-HW/
# !git clone https://github.com/meharkhurana03/16831-S26-HW-mehark.git 16831-S26-HW
# %cd 16831-S26-HW/hw1
# %pip install -r requirements_colab.txt
# %pip install -e .
# Out:
# [Errno 2] No such file or directory: '$SYM_PATH'
# /content/16831-S26-HW/hw1
# Cloning into '16831-S26-HW'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 92 (delta 25), reused 92 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (92/92), 6.13 MiB | 11.55 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# /content/16831-S26-HW/hw1/16831-S26-HW/hw1
# Requirement already satisfied: numpy>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 1)) (2.0.2)
# Requirement already satisfied: gym==0.25.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 6)) (0.25.1)
# Requirement already satisfied: tensorboard==2.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 7)) (2.10.0)
# Requirement already satisfied: tensorboardX==2.5.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 8)) (2.5.1)
# Requirement already satisfied: matplotlib<3.10,>=3.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 10)) (3.9.4)
# Requirement already satisfied: torch>=1.12.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 11)) (2.9.0+cu126)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 12)) (3.0)
# Requirement already satisfied: IPython in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 13)) (7.34.0)
# Requirement already satisfied: gym-notebook-wrapper in /usr/local/lib/python3.12/dist-packages (from -r requirements_colab.txt (line 14)) (1.3.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gym==0.25.1->-r requirements_colab.txt (line 6)) (3.1.2)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.12/dist-packages (from gym==0.25.1->-r requirements_colab.txt (line 6)) (0.1.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (1.4.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (1.76.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (2.47.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (3.10.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (3.19.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (2.32.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (75.2.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (3.1.5)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (0.46.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.10,>=3.8->-r requirements_colab.txt (line 10)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.10,>=3.8->-r requirements_colab.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.10,>=3.8->-r requirements_colab.txt (line 10)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.10,>=3.8->-r requirements_colab.txt (line 10)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.10,>=3.8->-r requirements_colab.txt (line 10)) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.10,>=3.8->-r requirements_colab.txt (line 10)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.10,>=3.8->-r requirements_colab.txt (line 10)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.10,>=3.8->-r requirements_colab.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements_colab.txt (line 11)) (3.5.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from IPython->-r requirements_colab.txt (line 13)) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from IPython->-r requirements_colab.txt (line 13)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from IPython->-r requirements_colab.txt (line 13)) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from IPython->-r requirements_colab.txt (line 13)) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from IPython->-r requirements_colab.txt (line 13)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from IPython->-r requirements_colab.txt (line 13)) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from IPython->-r requirements_colab.txt (line 13)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from IPython->-r requirements_colab.txt (line 13)) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from IPython->-r requirements_colab.txt (line 13)) (4.9.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.12/dist-packages (from gym-notebook-wrapper->-r requirements_colab.txt (line 14)) (1.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (2.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->IPython->-r requirements_colab.txt (line 13)) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->IPython->-r requirements_colab.txt (line 13)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->-r requirements_colab.txt (line 13)) (0.5.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<3.10,>=3.8->-r requirements_colab.txt (line 10)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.12.1->-r requirements_colab.txt (line 11)) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (3.0.3)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.12/dist-packages (from moviepy->gym-notebook-wrapper->-r requirements_colab.txt (line 14)) (4.67.2)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.12/dist-packages (from moviepy->gym-notebook-wrapper->-r requirements_colab.txt (line 14)) (0.1.12)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.12/dist-packages (from moviepy->gym-notebook-wrapper->-r requirements_colab.txt (line 14)) (2.37.2)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from moviepy->gym-notebook-wrapper->-r requirements_colab.txt (line 14)) (0.6.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (0.6.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.10.0->-r requirements_colab.txt (line 7)) (3.3.1)
# Obtaining file:///content/16831-S26-HW/hw1/16831-S26-HW/hw1
#   Preparing metadata (setup.py) ... done
# Installing collected packages: rob831
#   Attempting uninstall: rob831
#     Found existing installation: rob831 0.1.0
#     Uninstalling rob831-0.1.0:
#       Successfully uninstalled rob831-0.1.0
#   Running setup.py develop for rob831
# Successfully installed rob831-0.1.0

# %%
# downloads mujoco from source
# !wget https://mujoco.org/download/mujoco210-linux-x86_64.tar.gz
# !tar xzvf mujoco210-linux-x86_64.tar.gz
# !mkdir -p ~/.mujoco
# !mv mujoco210 ~/.mujoco/mujoco210
# !rm mujoco*

# %pip install -U mujoco
# %pip install -U 'mujoco-py<2.2,>=2.1'
# %pip install -U pyvirtualdisplay
# %pip install -U gym-notebook-wrapper
# %pip install -U "cython<3"

# !cp /root/.mujoco/mujoco210/bin/*.so /usr/lib/x86_64-linux-gnu/
# Out:
# --2026-02-08 01:22:32--  https://mujoco.org/download/mujoco210-linux-x86_64.tar.gz
# Resolving mujoco.org (mujoco.org)... 216.239.38.21, 216.239.32.21, 216.239.36.21, ...
# Connecting to mujoco.org (mujoco.org)|216.239.38.21|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/google-deepmind/mujoco/releases/download/2.1.0/mujoco210-linux-x86_64.tar.gz [following]
# --2026-02-08 01:22:32--  https://github.com/google-deepmind/mujoco/releases/download/2.1.0/mujoco210-linux-x86_64.tar.gz
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/400501136/1f51148e-4e64-4a12-a400-d6f1e21be444?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-02-08T02%3A00%3A16Z&rscd=attachment%3B+filename%3Dmujoco210-linux-x86_64.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-02-08T01%3A00%3A05Z&ske=2026-02-08T02%3A00%3A16Z&sks=b&skv=2018-11-09&sig=YnP4Ux6fmyQN7%2FnB4qrEmfpxxDhVRzOXLxorxpf6oag%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3MDUxNDA1MywibmJmIjoxNzcwNTEzNzUzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.HSRd9v60tMIIWZ6NMfd2oVuFfPweVAj4xdu5CrArwZ8&response-content-disposition=attachment%3B%20filename%3Dmujoco210-linux-x86_64.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2026-02-08 01:22:33--  https://release-assets.githubusercontent.com/github-production-release-asset/400501136/1f51148e-4e64-4a12-a400-d6f1e21be444?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-02-08T02%3A00%3A16Z&rscd=attachment%3B+filename%3Dmujoco210-linux-x86_64.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-02-08T01%3A00%3A05Z&ske=2026-02-08T02%3A00%3A16Z&sks=b&skv=2018-11-09&sig=YnP4Ux6fmyQN7%2FnB4qrEmfpxxDhVRzOXLxorxpf6oag%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3MDUxNDA1MywibmJmIjoxNzcwNTEzNzUzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.HSRd9v60tMIIWZ6NMfd2oVuFfPweVAj4xdu5CrArwZ8&response-content-disposition=attachment%3B%20filename%3Dmujoco210-linux-x86_64.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4385135 (4.2M) [application/octet-stream]
# Saving to: ‘mujoco210-linux-x86_64.tar.gz’
#
# mujoco210-linux-x86 100%[===================>]   4.18M  12.3MB/s    in 0.3s
#
# 2026-02-08 01:22:33 (12.3 MB/s) - ‘mujoco210-linux-x86_64.tar.gz’ saved [4385135/4385135]
#
# mujoco210/
# mujoco210/THIRD_PARTY_NOTICES
# mujoco210/bin/
# mujoco210/bin/libglfw.so.3
# mujoco210/bin/derivative
# mujoco210/bin/libglew.so
# mujoco210/bin/record
# mujoco210/bin/simulate
# mujoco210/bin/libglewegl.so
# mujoco210/bin/testxml
# mujoco210/bin/basic
# mujoco210/bin/libglewosmesa.so
# mujoco210/bin/libglfw3.a
# mujoco210/bin/libmujoco210.so
# mujoco210/bin/compile
# mujoco210/bin/libmujoco210nogl.so
# mujoco210/bin/testspeed
# mujoco210/include/
# mujoco210/include/glfw3.h
# mujoco210/include/uitools.c
# mujoco210/include/mjxmacro.h
# mujoco210/include/mjui.h
# mujoco210/include/mjrender.h
# mujoco210/include/mjmodel.h
# mujoco210/include/mjdata.h
# mujoco210/include/mujoco.h
# mujoco210/include/mjvisualize.h
# mujoco210/include/uitools.h
# mujoco210/model/
# mujoco210/model/humanoid100.xml
# mujoco210/model/arm26.xml
# mujoco210/model/carpet.png
# mujoco210/model/softbox.xml
# mujoco210/model/grid2pin.xml
# mujoco210/model/sponge.png
# mujoco210/model/hammock.xml
# mujoco210/model/cloth.xml
# mujoco210/model/grid2.xml
# mujoco210/model/grid1.xml
# mujoco210/model/grid1pin.xml
# mujoco210/model/softellipsoid.xml
# mujoco210/model/softcylinder.xml
# mujoco210/model/marble.png
# mujoco210/model/rope.xml
# mujoco210/model/particle.xml
# mujoco210/model/loop.xml
# mujoco210/model/humanoid.xml
# mujoco210/model/scene.xml
# mujoco210/sample/
# mujoco210/sample/derivative.cc
# mujoco210/sample/testspeed.cc
# mujoco210/sample/Makefile
# mujoco210/sample/basic.cc
# mujoco210/sample/record.cc
# mujoco210/sample/compile.cc
# mujoco210/sample/simulate.cc
# mujoco210/sample/testxml.cc
# Requirement already satisfied: mujoco in /usr/local/lib/python3.12/dist-packages (3.4.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco) (1.13.0)
# Requirement already satisfied: glfw in /usr/local/lib/python3.12/dist-packages (from mujoco) (2.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mujoco) (2.0.2)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco) (3.1.10)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco) (4.15.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco) (3.23.0)
# Requirement already satisfied: mujoco-py<2.2,>=2.1 in /usr/local/lib/python3.12/dist-packages (2.1.2.14)
# Requirement already satisfied: glfw>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from mujoco-py<2.2,>=2.1) (2.10.0)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.12/dist-packages (from mujoco-py<2.2,>=2.1) (2.0.2)
# Requirement already satisfied: Cython>=0.27.2 in /usr/local/lib/python3.12/dist-packages (from mujoco-py<2.2,>=2.1) (0.29.37)
# Requirement already satisfied: imageio>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from mujoco-py<2.2,>=2.1) (2.37.2)
# Requirement already satisfied: cffi>=1.10 in /usr/local/lib/python3.12/dist-packages (from mujoco-py<2.2,>=2.1) (2.0.0)
# Requirement already satisfied: fasteners~=0.15 in /usr/local/lib/python3.12/dist-packages (from mujoco-py<2.2,>=2.1) (0.20)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.10->mujoco-py<2.2,>=2.1) (3.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio>=2.1.2->mujoco-py<2.2,>=2.1) (11.3.0)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.12/dist-packages (3.0)
# Requirement already satisfied: gym-notebook-wrapper in /usr/local/lib/python3.12/dist-packages (1.3.3)
# Requirement already satisfied: gym in /usr/local/lib/python3.12/dist-packages (from gym-notebook-wrapper) (0.25.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from gym-notebook-wrapper) (3.9.4)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.12/dist-packages (from gym-notebook-wrapper) (3.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from gym-notebook-wrapper) (7.34.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.12/dist-packages (from gym-notebook-wrapper) (1.0.3)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from gym->gym-notebook-wrapper) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gym->gym-notebook-wrapper) (3.1.2)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.12/dist-packages (from gym->gym-notebook-wrapper) (0.1.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->gym-notebook-wrapper) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython->gym-notebook-wrapper) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->gym-notebook-wrapper) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->gym-notebook-wrapper) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->gym-notebook-wrapper) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->gym-notebook-wrapper) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->gym-notebook-wrapper) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->gym-notebook-wrapper) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->gym-notebook-wrapper) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->gym-notebook-wrapper) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym-notebook-wrapper) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym-notebook-wrapper) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym-notebook-wrapper) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym-notebook-wrapper) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym-notebook-wrapper) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym-notebook-wrapper) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym-notebook-wrapper) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->gym-notebook-wrapper) (2.9.0.post0)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.12/dist-packages (from moviepy->gym-notebook-wrapper) (4.67.2)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.12/dist-packages (from moviepy->gym-notebook-wrapper) (2.32.4)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.12/dist-packages (from moviepy->gym-notebook-wrapper) (0.1.12)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.12/dist-packages (from moviepy->gym-notebook-wrapper) (2.37.2)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from moviepy->gym-notebook-wrapper) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->gym-notebook-wrapper) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->gym-notebook-wrapper) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->gym-notebook-wrapper) (0.5.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->gym-notebook-wrapper) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy->gym-notebook-wrapper) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy->gym-notebook-wrapper) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy->gym-notebook-wrapper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy->gym-notebook-wrapper) (2026.1.4)
# Requirement already satisfied: cython<3 in /usr/local/lib/python3.12/dist-packages (0.29.37)

# %%
# set env variables
import os
os.environ['LD_LIBRARY_PATH'] += ':/root/.mujoco/mujoco210/bin'
os.environ['MUJOCO_PY_MUJOCO_PATH'] = '/root/.mujoco/mujoco210'
os.environ['LD_LIBRARY_PATH'] += ':/usr/lib/nvidia'

# %%
#@title set up virtual display

from pyvirtualdisplay import Display

display = Display(visible=0, size=(1400, 900))
display.start()

# %%
#@title test virtual display

#@markdown If you see a video of a four-legged ant fumbling about, setup is complete!

import numpy as np
if not hasattr(np, "bool8"):
    np.bool8 = np.bool_

import gym
import gnwrapper

env = gnwrapper.LoopAnimation(gym.make('Ant-v2'))

observation = env.reset()
for i in range(100):
    obs, rew, term, _ = env.step(env.action_space.sample())
    env.render()
    if term:
      break

env.display()
env.close()
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## Editing Code
#
# To edit code, click the folder icon on the left menu. Navigate to the corresponding file (`hw_16831/...`). Double click a file to open an editor. There is a timeout of about ~12 hours with Colab while it is active (and less if you close your browser window). We sync your edits to Google Drive so that you won't lose your work in the event of an instance timeout, but you will need to re-mount your Google Drive and re-install packages with every new instance.
#
# **IMPORTANT**: Please re-run the following cell before every code run.

# %%
#@title imports
#@markdown Please re-run this cell before every code run

import os
import time
import importlib

import rob831.policies.MLP_policy
import rob831.policies.loaded_gaussian_policy
import rob831.agents.bc_agent
import rob831.infrastructure.rl_trainer
import rob831.infrastructure.utils

importlib.reload(rob831.policies.MLP_policy)
importlib.reload(rob831.policies.loaded_gaussian_policy)
importlib.reload(rob831.agents.bc_agent)
importlib.reload(rob831.infrastructure.rl_trainer)
importlib.reload(rob831.infrastructure.utils)

from rob831.infrastructure.rl_trainer import RL_Trainer
from rob831.agents.bc_agent import BCAgent
from rob831.policies.loaded_gaussian_policy import LoadedGaussianPolicy
# Out:
# /usr/local/lib/python3.12/dist-packages/google/protobuf/internal/well_known_types.py:92: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   _EPOCH_DATETIME = datetime.utcfromtimestamp(0)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/tensorboardX/proto/resource_handle_pb2.py:18: DeprecationWarning: Call to deprecated create function FileDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   DESCRIPTOR = _descriptor.FileDescriptor(
# /usr/local/lib/python3.12/dist-packages/tensorboardX/proto/resource_handle_pb2.py:36: DeprecationWarning: Call to deprecated create function FieldDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _descriptor.FieldDescriptor(
# /usr/local/lib/python3.12/dist-packages/tensorboardX/proto/resource_handle_pb2.py:29: DeprecationWarning: Call to deprecated create function Descriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _RESOURCEHANDLEPROTO = _descriptor.Descriptor(
# /usr/local/lib/python3.12/dist-packages/tensorboardX/proto/tensor_shape_pb2.py:18: DeprecationWarning: Call to deprecated create function FileDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   DESCRIPTOR = _descriptor.FileDescriptor(
# /usr/local/lib/python3.12/dist-packages/tensorboardX/proto/tensor_shape_pb2.py:36: DeprecationWarning: Call to deprecated create function FieldDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _descriptor.FieldDescriptor(
# /usr/local/lib/python3.12/dist-packages/tensorboardX/proto/tensor_shape_pb2.py:29: DeprecationWarning: Call to deprecated create function Descriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _TENSORSHAPEPROTO_DIM = _descriptor.Descriptor(
# /usr/local/lib/python3.12/dist-packages/tensorboardX/proto/types_pb2.py:19: DeprecationWarning: Call to deprecated create function FileDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   DESCRIPTOR = _descriptor.FileDescriptor(
# /usr/local/lib/python3.12/dist-packages/tensorboardX/proto/types_pb2.py:33: DeprecationWarning: Call to deprecated create function EnumValueDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _descriptor.EnumValueDescriptor(
# /usr/local/lib/python3.12/dist-packages/tensorboardX/proto/types_pb2.py:27: DeprecationWarning: Call to deprecated create function EnumDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _DATATYPE = _descriptor.EnumDescriptor(
# /usr/local/lib/python3.12/dist-packages/tensorboardX/proto/tensor_pb2.py:21: DeprecationWarning: Call to deprecated create function FileDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   DESCRIPTOR = _descriptor.FileDescriptor(
# /usr/local/lib/python3.12/dist-packages/tensorboardX/proto/tensor_pb2.py:40: DeprecationWarning: Call to deprecated create function FieldDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _descriptor.FieldDescriptor(
# /usr/local/lib/python3.12/dist-packages/tensorboardX/proto/tensor_pb2.py:33: DeprecationWarning: Call to deprecated create function Descriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _TENSORPROTO = _descriptor.Descriptor(
# /usr/local/lib/python3.12/dist-packages/tensorboardX/proto/summary_pb2.py:19: DeprecationWarning: Call to deprecated create function FileDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   DESCRIPTOR = _descriptor.FileDescriptor(
# /usr/local/lib/python3.12/dist-packages/tensorboardX/proto/summary_pb2.py:38: DeprecationWarning: Call to deprecated create function FieldDescriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _descriptor.FieldDescriptor(
# /usr/local/lib/python3.12/dist-packages/tensorboardX/proto/summary_pb2.py:31: DeprecationWarning: Call to deprecated create function Descriptor(). Note: Create unlinked descriptors is going to go away. Please use get/find descriptors from generated code or query the descriptor_pool.
#   _SUMMARYDESCRIPTION = _descriptor.Descriptor(

# %% [markdown]
# ## Run Behavior Cloning (Problem 1)

# %%
#@title runtime arguments

class Args:

  def __getitem__(self, key):
    return getattr(self, key)

  def __setitem__(self, key, val):
    setattr(self, key, val)

  #@markdown expert data
  expert_policy_file = '/content/hw_16831/16831-S26-HW/hw1/rob831/policies/experts/Ant.pkl' #@param
  expert_data = '/content/hw_16831/16831-S26-HW/hw1/rob831/expert_data/expert_data_Ant-v2.pkl' #@param
  env_name = 'Ant-v2' #@param ['Ant-v2', 'Humanoid-v2', 'Walker2d-v2', 'HalfCheetah-v2', 'Hopper-v2']
  exp_name = 'test_bc_ant' #@param
  do_dagger = False #@param {type: "boolean"}
  ep_len = 1000 #@param {type: "integer"}
  save_params = False #@param {type: "boolean"}

  num_agent_train_steps_per_iter = 1000 #@param {type: "integer"})
  n_iter = 1 #@param {type: "integer"})

  #@markdown batches & buffers
  batch_size = 1000 #@param {type: "integer"})
  eval_batch_size = 1000 #@param {type: "integer"}
  train_batch_size = 100 #@param {type: "integer"}
  max_replay_buffer_size = 1000000 #@param {type: "integer"}

  #@markdown network
  n_layers = 2 #@param {type: "integer"}
  size = 64 #@param {type: "integer"}
  learning_rate = 5e-3 #@param {type: "number"}

  #@markdown logging
  video_log_freq = 5 #@param {type: "integer"}
  scalar_log_freq = 1 #@param {type: "integer"}

  #@markdown gpu & run-time settings
  no_gpu = False #@param {type: "boolean"}
  which_gpu = 0 #@param {type: "integer"}
  seed = 1 #@param {type: "integer"}

args = Args()

# %%
#@title define `BC_Trainer`
class BC_Trainer(object):

    def __init__(self, params):
        #######################
        ## AGENT PARAMS
        #######################

        agent_params = {
            'n_layers': params['n_layers'],
            'size': params['size'],
            'learning_rate': params['learning_rate'],
            'max_replay_buffer_size': params['max_replay_buffer_size'],
            }

        self.params = params
        self.params['agent_class'] = BCAgent ## TODO: look in here and implement this
        self.params['agent_params'] = agent_params

        ################
        ## RL TRAINER
        ################

        self.rl_trainer = RL_Trainer(self.params) ## TODO: look in here and implement this

        #######################
        ## LOAD EXPERT POLICY
        #######################

        print('Loading expert policy from...', self.params['expert_policy_file'])
        self.loaded_expert_policy = LoadedGaussianPolicy(self.params['expert_policy_file'])
        print('Done restoring expert policy...')

    def run_training_loop(self):

        self.rl_trainer.run_training_loop(
            n_iter=self.params['n_iter'],
            initial_expertdata=self.params['expert_data'],
            collect_policy=self.rl_trainer.agent.actor,
            eval_policy=self.rl_trainer.agent.actor,
            relabel_with_expert=self.params['do_dagger'],
            expert_policy=self.loaded_expert_policy,
        )

# %%
#@title create directory for logging

if args.do_dagger:
    logdir_prefix = 'q2_'
    assert args.n_iter>1, ('DAgger needs more than 1 iteration (n_iter>1) of training, to iteratively query the expert and train (after 1st warmstarting from behavior cloning).')
else:
    logdir_prefix = 'q1_'
    assert args.n_iter==1, ('Vanilla behavior cloning collects expert data just once (n_iter=1)')

data_path ='/content/hw_16831/hw1/data'
if not (os.path.exists(data_path)):
    os.makedirs(data_path)
logdir = logdir_prefix + args.exp_name + '_' + args.env_name + \
         '_' + time.strftime("%d-%m-%Y_%H-%M-%S")
logdir = os.path.join(data_path, logdir)
args['logdir'] = logdir
if not(os.path.exists(logdir)):
    os.makedirs(logdir)

# %%
# Make sure you're in the 16831-F25-HW/hw1 folder when running this.
# %cd /content/hw_16831/16831-F25-HW/hw1
## run training
print(args.logdir)
trainer = BC_Trainer(args)
trainer.run_training_loop()
# Out:
# [Errno 2] No such file or directory: '/content/hw_16831/16831-F25-HW/hw1'
# /content
# /content/hw_16831/hw1/data/q1_test_bc_ant_Ant-v2_08-02-2026_01-37-00
# ########################
# logging outputs to  /content/hw_16831/hw1/data/q1_test_bc_ant_Ant-v2_08-02-2026_01-37-00
# ########################
# Using GPU id 0
# Loading expert policy from... /content/hw_16831/16831-S26-HW/hw1/rob831/policies/experts/Ant.pkl
# obs (1, 111) (1, 111)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent using sampled data from replay buffer...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1299139430.py in <cell line: 0>()
#       4 print(args.logdir)
#       5 trainer = BC_Trainer(args)
# ----> 6 trainer.run_training_loop()
#
# /tmp/ipython-input-2558457091.py in run_training_loop(self)
#      34     def run_training_loop(self):
#      35
# ---> 36         self.rl_trainer.run_training_loop(
#      37             n_iter=self.params['n_iter'],
#      38             initial_expertdata=self.params['expert_data'],
#
# /content/gdrive/MyDrive/hw_16831/16831-S26-HW/hw1/rob831/infrastructure/rl_trainer.py in run_training_loop(self, n_iter, collect_policy, eval_policy, initial_expertdata, relabel_with_expert, start_relabel_with_expert, expert_policy)
#     130
#     131             # train agent (using sampled data from replay buffer)
# --> 132             training_logs = self.train_agent()  # HW1: implement this function below
#     133
#     134             # log/save
#
# /content/gdrive/MyDrive/hw_16831/16831-S26-HW/hw1/rob831/infrastructure/rl_trainer.py in train_agent(self)
#     207             # HINT: use the agent's train function
#     208             # HINT: keep the agent's training log for debugging
# --> 209             train_log = self.agent.train(obs_batch, acs_batch, rews_batch, next_obs_batch, terminals_batch)
#     210
#     211             all_logs.append(train_log)
#
# /content/gdrive/MyDrive/hw_16831/16831-S26-HW/hw1/rob831/agents/bc_agent.py in train(self, ob_no, ac_na, re_n, next_ob_no, terminal_n)
#      28         # training a BC agent refers to updating its actor using
#      29         # the given observations and corresponding action labels
# ---> 30         log = self.actor.update(ob_no, ac_na)  # HW1: you will modify this
#      31         return log
#      32
#
# /content/gdrive/MyDrive/hw_16831/16831-S26-HW/hw1/rob831/policies/MLP_policy.py in update(self, observations, actions, adv_n, acs_labels_na, qvals)
#     110     ):
#     111         # TODO: update the policy and return the loss
# --> 112         loss = TODO
#     113
#     114         return {
#
# NameError: name 'TODO' is not defined

# %%
#@markdown You can visualize your runs with tensorboard from within the notebook

# %load_ext tensorboard
# %tensorboard --logdir /content/hw_16831/hw1/data

# %% [markdown]
# ## Running DAgger (Problem 2)
# Modify the settings above:
# 1. check the `do_dagger` box
# 2. set `n_iters` to `10`
# and then rerun the code.
